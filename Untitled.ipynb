# %%
a=np.array(((67,678,90),(456,456,987)))
z=a[1]+a[0]
z
# Out:
# array([ 523, 1134, 1077])

# %%
from matplotlib import pyplot as plt
import numpy as np

a=np.array([1,2,3,4,5])
b=np.array([1,4,9,16,25])
size=np.array([1,2,3,4,5])

color=["red","pink","#f5f555"]
plt.plot(a,b,"go-",label="x-axis")
plt.loglog(a,b**12,"bs-",label="y-axis")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.legend(loc="upper left")
plt.show()
plt.savefig("myplot.pdf")

# %%
import numpy as np
from matplotlib import pyplot as plt
y=np.random.normal(size=100000)
x=np.random.normal(size=100000)
c=["red","green","blue","pink"]
plt.scatter(x,y,c=c)
plt.show()
plt.savefig("graph.jpg")

# %%
help(input)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d3295183536f> in <module>()
# ----> 1 help(input.strip)
#
# AttributeError: 'function' object has no attribute 'strip'
