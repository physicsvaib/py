# %%
import numpy as np
a=np.array(((67,678,90),(456,456,987)))
z=a[1]+a[0]
z

# %%
from matplotlib import pyplot as plt
a=np.array([1,2,3,4,5])
b=np.array([1,4,9,16,25])
size=np.array([1,2,3,4,5])
color=["red","pink","#f5f555"]
plt.plot(a,b,"go--",linewidth=2,markersize=20,label="x-axis")
plt.plot(a,b**2,"bs-",linewidth=2,markersize=20,label="y-axis")
plt.xlabel("$X$")
plt.ylabel("$Y$")
plt.legend(loc="upper left")
plt.show()
plt.savefig("myplot.pdf")
